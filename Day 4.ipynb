# %%
# importing necessary libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the dataset
df = pd.read_csv('Student_Behaviour.csv')
# load top 5 rows
df.head()
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       69.5
# 3                  Yes  Female        BCA       147.0        20.0       70.0
# 4                   No    Male        BCA       170.0        54.0       40.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 0       65.0          80.0    Video Games      0 - 30 minute
# 1       80.0          70.0         Cinema     30 - 60 minute
# 2       61.0          55.0         Cinema         1 - 2 Hour
# 3       59.0          58.0  Reading books         1 - 2 Hour
# 4       65.0          30.0    Video Games     30 - 60 minute
#
#   prefer to study in  salary expectation Do you like your degree?  \
# ...

# %%
# number of rows and columns
df.shape
# Out:
# (235, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 19 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Certification Course                                    235 non-null    object
#  1   Gender                                                  235 non-null    object
#  2   Department                                              235 non-null    object
#  3   Height(CM)                                              235 non-null    float64
#  4   Weight(KG)                                              235 non-null    float64
#  5   10th Mark                                               235 non-null    float64
#  6   12th Mark                                               235 non-null    float64
#  7   college mark                                            235 non-null    float64
# ...

# %%
# stat of data set
df.describe()
# Out:
#        Height(CM)  Weight(KG)   10th Mark   12th Mark  college mark  \
# count  235.000000  235.000000  235.000000  235.000000    235.000000
# mean   157.402128   60.803830   76.842128   68.780128     70.660553
# std     21.510805   14.895844   13.050800   11.016533     15.727446
# min      4.500000   20.000000    7.400000   45.000000      1.000000
# 25%    152.000000   50.000000   70.000000   60.000000     60.000000
# 50%    160.000000   60.000000   80.000000   69.000000     70.000000
# 75%    170.000000   70.000000   86.250000   76.000000     80.000000
# max    192.000000  106.000000   98.000000   94.000000    100.000000
#
#        salary expectation
# count        2.350000e+02
# mean         3.248168e+04
# std          1.113146e+05
# min          0.000000e+00
# 25%          1.500000e+04
# 50%          2.000000e+04
# 75%          2.500000e+04
# max          1.500000e+06

# %%
# missing values
df.isnull().sum()
# Out:
# Certification Course                                      0
# Gender                                                    0
# Department                                                0
# Height(CM)                                                0
# Weight(KG)                                                0
# 10th Mark                                                 0
# 12th Mark                                                 0
# college mark                                              0
# hobbies                                                   0
# daily studing time                                        0
# prefer to study in                                        0
# salary expectation                                        0
# Do you like your degree?                                  0
# willingness to pursue a career based on their degree      0
# social medai & video                                      0
# Travelling Time                                           0
# ...

# %%
df.columns
# Out:
# Index(['Certification Course', 'Gender', 'Department', 'Height(CM)',
#        'Weight(KG)', '10th Mark', '12th Mark', 'college mark', 'hobbies',
#        'daily studing time', 'prefer to study in', 'salary expectation',
#        'Do you like your degree?',
#        'willingness to pursue a career based on their degree  ',
#        'social medai & video', 'Travelling Time ', 'Stress Level ',
#        'Financial Status', 'part-time job'],
#       dtype='object')

# %%
df.Gender
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 230      Male
# 231      Male
# 232    Female
# 233    Female
# 234    Female
# Name: Gender, Length: 235, dtype: object

# %%
#rows
df.loc[4:9]
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 4                   No    Male        BCA       170.0        54.0       40.0
# 5                  Yes  Female        BCA       139.0        33.0       90.0
# 6                  Yes    Male        BCA       165.0        50.0       70.0
# 7                   No    Male        BCA       152.0        43.0       61.6
# 8                   No    Male        BCA       190.0        85.0       88.2
# 9                   No    Male        BCA       150.0        84.0       60.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 4      65.00          30.0    Video Games     30 - 60 minute
# 5      75.00          70.0         Cinema     30 - 60 minute
# 6      63.00           3.0  Reading books         1 - 2 Hour
# 7      61.67          75.0         Sports         1 - 2 Hour
# 8      67.50          60.0    Video Games      0 - 30 minute
# ...

# %%
# integer loc - row as well as col
df.iloc[4:9,1:3]
# Out:
#    Gender Department
# 4    Male        BCA
# 5  Female        BCA
# 6    Male        BCA
# 7    Male        BCA
# 8    Male        BCA

# %%
df1= df.rename(columns = {'Certification Course':'Certification_Course',  'Stress Level':'Stress_Level'})

# %%
df1.columns                 #df1 must be used and df gives the old names
# Out:
# Index(['Certification_Course', 'Gender', 'Department', 'Height(CM)',
#        'Weight(KG)', '10th Mark', '12th Mark', 'college mark', 'hobbies',
#        'daily studing time', 'prefer to study in', 'salary expectation',
#        'Do you like your degree?',
#        'willingness to pursue a career based on their degree  ',
#        'social medai & video', 'Travelling Time ', 'Stress Level ',
#        'Financial Status', 'part-time job'],
#       dtype='object')

# %%
df.Gender
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 230      Male
# 231      Male
# 232    Female
# 233    Female
# 234    Female
# Name: Gender, Length: 235, dtype: object

# %%
df.Gender.value_counts().plot(kind='bar')
plt.title('Bar plot on gender')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.Gender.value_counts().plot(kind='pie')
plt.title('pie chart on gender')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Department'].value_counts().plot(kind='pie', autopct='%1.2f%%')
plt.title('pie chart based on department')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Univariate analysis - uni means single - variate - variable   use histogram
sns.histplot(data=df,x='Certification Course')
plt.show()

# %%
sns.histplot(data=df,x='10th Mark',kde = True)   # left skewed - outlier is the mark btw 0 and 20
plt.show()

# %%
df['Travelling Time '].value_counts()
# Out:
# Travelling Time
# 30 - 60 minutes     80
# 0 - 30 minutes      55
# 1 - 1.30 hour       51
# 1.30 - 2 hour       18
# 2 - 2.30 hour       14
# more than 3 hour    10
# 2.30 - 3 hour        7
# Name: count, dtype: int64

# %%
sns.histplot(data = df , x= 'Travelling Time ', bins = 30, color ='r')
# Out:
# <Axes: xlabel='Travelling Time ', ylabel='Count'>

# %%
# Bi - variate analysis: 2 variables - 1 on x axis and other on y
sns.barplot(data=df, x='10th Mark',y='12th Mark' , color = 'g')
plt.title('Bi variate analysis using Bar plot')
plt.show()

# %%
sns.scatterplot(data=df, x='Height(CM)',y='Weight(KG)')
plt.title('Scatter plot')
plt.show()

# %%
sns.countplot(data= df, x='Stress Level ', hue = 'Department')                 # the box at right top corner named department is called as legend
plt.title('Count plot')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# multi variate - heatmap - correlation
num_cols = df.select_dtypes(include = 'number')
num_cols
# Out:
#      Height(CM)  Weight(KG)  10th Mark  12th Mark  college mark  \
# 0         100.0        58.0       79.0       65.0          80.0
# 1          90.0        40.0       70.0       80.0          70.0
# 2         159.0        78.0       69.5       61.0          55.0
# 3         147.0        20.0       70.0       59.0          58.0
# 4         170.0        54.0       40.0       65.0          30.0
# ..          ...         ...        ...        ...           ...
# 230       170.0        76.0       72.0       67.0          65.0
# 231       172.0        52.0       72.0       70.0          76.0
# 232       139.0        33.0       90.0       75.0          70.0
# 233       153.0        58.0       85.0       74.0          75.0
# 234       155.0        39.0       45.0       45.0          50.0
#
#      salary expectation
# 0                 40000
# 1                 15000
# 2                 13000
# 3               1500000
# 4                 50000
# ..                  ...
# ...

# %%
cm = num_cols.corr()                   # corr- correlation
cm
# Out:
#                     Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# Height(CM)            1.000000    0.275948   0.019896  -0.120672
# Weight(KG)            0.275948    1.000000   0.062394  -0.019208
# 10th Mark             0.019896    0.062394   1.000000   0.473618
# 12th Mark            -0.120672   -0.019208   0.473618   1.000000
# college mark         -0.018535   -0.014901   0.466234   0.425123
# salary expectation   -0.010708   -0.087787  -0.055694  -0.085610
#
#                     college mark  salary expectation
# Height(CM)             -0.018535           -0.010708
# Weight(KG)             -0.014901           -0.087787
# 10th Mark               0.466234           -0.055694
# 12th Mark               0.425123           -0.085610
# college mark            1.000000           -0.103034
# salary expectation     -0.103034            1.000000

# %%
sns.heatmap(cm,annot=True )              # annot - annotation
# Out:
# <Axes: >

# %%
sns.heatmap(cm,annot=True , cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
#pairplot
sns.pairplot(data=df)

# %%
 #filtering
df[df['Department']=='BCA'].shape[0]                      # eg. first df is entering dept and next one is entering bca
# Out:
# 132

# %%
df[(df['Department']=='BCA') & (df['Gender']=='Female')].shape[0]                                 #using parentheses coz dealing it bitwise
# Out:
# 38

# %%
df[(df['Department']=='Commerce') & (df['Gender']=='Male')].shape[0]
# Out:
# 31

# %%
df[(df['Department']=='BCA') & (df['Gender']=='Female')].shape[0]
# Out:
# 38

# %%
df['Stress Level '].unique()
# Out:
# array(['Bad', 'Awful', 'Good', 'fabulous'], dtype=object)

# %%
df[(df['Stress Level ']=='Bad')].shape[0]
# Out:
# 68

# %%
df[(df['Stress Level ']=='fabulous')&(df['Department']=='BCA')].shape[0]
# Out:
# 3

# %%
sns.histplot(data=df,x='prefer to study in')
plt.show()

# %%
df['prefer to study in'].value_counts().plot(kind='pie', autopct='%1.2f%%')
plt.title('pie chart')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(data= df, x='prefer to study in', hue = 'college mark')                 # the box at right top corner named department is called as legend
plt.title('Count plot')                    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(data= df, x='prefer to study in', hue = 'salary expectation')                 # the box at right top corner named department is called as legend
plt.title('Count plot')                    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
max=df[ 'salary expectation'].max()
max
# Out:
# 1500000

# %%
avg_sal=df[ 'salary expectation'].mean()
avg_sal
# Out:
# 32481.68085106383

# %%
# Box plot
sns.boxplot(data=df,x='Department')
plt.show()
